# %%
pip install chembl-downloader
# Out:
# ...
#      ---------------------------------------- 50.8/50.8 kB 2.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 6.1/6.1 MB 14.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.1/2.1 MB 10.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 48.8/48.8 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 95.1/95.1 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for click-default-group: filename=click_default_group-1.2.2-py3-none-any.whl size=3383 sha256=b6e807d5592122885fabffa485fc65a096d00d2ab69c974485f7931f7edf9ac1
# ...

# %%
import chembl_downloader
import chembl_webresource_client
import pandas as pd
import csv

# %%
from chembl_webresource_client.query
# Out:
#   File "C:\Users\Jonas\AppData\Local\Temp\ipykernel_2364\432531683.py", line 1
#     from chembl_webresource_client.query
#                                         ^
# SyntaxError: invalid syntax

# %%
from chembl_webresource_client.new_client import new_client

molecule = new_client.molecule
no_violations = molecule.filter(molecule_properties__num_ro5_violations=0)
len(no_violations)
# Out:
# 1619916

# %%
df_new = pd.read_excel('chembl_300Da.xlsx')
df_new
# Out:
#             ChEMBL ID         Name  Molecular Weight  Targets  AlogP  \
# 0        CHEMBL539070          NaN            286.79      1.0   2.28
# 1       CHEMBL3483397          NaN            275.36     16.0   1.64
# 2       CHEMBL1374265          NaN            209.68      8.0   3.82
# 3       CHEMBL3747929          NaN            277.35      NaN   2.99
# 4       CHEMBL1940440          NaN            249.62     12.0   2.07
# ...               ...          ...               ...      ...    ...
# 318040   CHEMBL141246          NaN            231.30      2.0   1.63
# 318041  CHEMBL1865258  CLOFENAMIDE            270.72      3.0  -0.37
# 318042  CHEMBL1420130          NaN            226.30      2.0   1.89
# 318043  CHEMBL1573359          NaN            265.33      3.0   2.04
# 318044   CHEMBL213734          NaN            288.26      2.0   2.32
#
#         Polar Surface Area  HBA  HBD  #RO5 Violations  #Rotatable Bonds  ...  \
# ...

# %%
del df_new['Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df_new
# Out:
#             ChEMBL ID  Molecular Weight  Targets  AlogP  Polar Surface Area  \
# 0        CHEMBL539070            286.79      1.0   2.28               73.06
# 1       CHEMBL3483397            275.36     16.0   1.64               66.93
# 2       CHEMBL1374265            209.68      8.0   3.82               26.03
# 3       CHEMBL3747929            277.35      NaN   2.99               25.36
# 4       CHEMBL1940440            249.62     12.0   2.07               97.60
# ...               ...               ...      ...    ...                 ...
# 318040   CHEMBL141246            231.30      2.0   1.63               45.78
# 318041  CHEMBL1865258            270.72      3.0  -0.37              120.32
# 318042  CHEMBL1420130            226.30      2.0   1.89               63.08
# 318043  CHEMBL1573359            265.33      3.0   2.04               57.61
# 318044   CHEMBL213734            288.26      2.0   2.32              101.70
#
# ...

# %%
del df_new['Inorganic Flag']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Inorganic Flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
del df_new['#RO5 Violations']
del df_new['#RO5 Violations (Lipinski)']

# %%
df_clean = df_new.dropna()

# %%
df_clean
# Out:
#             ChEMBL ID  Molecular Weight  Targets  AlogP  Polar Surface Area  \
# 0        CHEMBL539070            286.79      1.0   2.28               73.06
# 1       CHEMBL3483397            275.36     16.0   1.64               66.93
# 2       CHEMBL1374265            209.68      8.0   3.82               26.03
# 4       CHEMBL1940440            249.62     12.0   2.07               97.60
# 6       CHEMBL1337107            296.33      2.0   2.29               64.35
# ...               ...               ...      ...    ...                 ...
# 318040   CHEMBL141246            231.30      2.0   1.63               45.78
# 318041  CHEMBL1865258            270.72      3.0  -0.37              120.32
# 318042  CHEMBL1420130            226.30      2.0   1.89               63.08
# 318043  CHEMBL1573359            265.33      3.0   2.04               57.61
# 318044   CHEMBL213734            288.26      2.0   2.32              101.70
#
# ...

# %%
df_clean.to_excel('chembl_clean.xlsx')
